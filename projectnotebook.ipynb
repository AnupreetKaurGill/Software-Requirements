# %% [markdown]
# # TASK 1: GATHERING REVIEWS

# %% [markdown]
# ### Assigned App 1

# %% [markdown]
# App : Meteroid,
# number of reviews: 2168,
# Reviews are sorted by MOST_RELEVANT. Meteroid has only one review available. Therefore, all other reviews are taken from similar and competitor apps.

# %% [markdown]
# ### Assigned App 2

# %% [markdown]
# App : Rainwave, number of reviews: 1100, Reviews are sorted by MOST_RELEVANT

# %% [markdown]
# ### Assigned App 3

# %% [markdown]
# App : Nextcloud Notes, number of reviews: 1575, Reviews are sorted by MOST_RELEVANT

# %% [markdown]
# ### Assigned App 4

# %% [markdown]
# App : Pomfshare, number of reviews: 1830, Reviews are sorted by MOST_RELEVANT. Pomfshare does not have any review. So, all the reviews are gathered from similar and competitor reviews

# %% [markdown]
# ### Assigned App 5

# %% [markdown]
# App : Quasseldroid, number of reviews: 1330, Reviews are sorted by MOST_RELEVANT

# %% [markdown]
# #  TASK 2: PREPROCESS YOUR TEXT

# %%
pip install num2words
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_colwidth',800)
description = pd.read_csv("de.chaosdorf.meteroid.csv")
description2 = pd.read_csv("cc.rainwave.android.csv")
description3 = pd.read_csv("it.niedermann.owncloud.notes.csv")
description4 = pd.read_csv("science.itaintrocket.pomfshare.csv")
description5 = pd.read_csv("com.iskrembilen.quasseldroid.csv")

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# ## pre-processing code snippet

# %%
import string
#print(string.punctuation)

def remove_punctuation(text):
    text_nopunct = "".join([c for c in text if c not in string.punctuation])
    return text_nopunct

import re

def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

def remove_special_chars(text):
    return(re.sub(r"\W+|_", " ", text)) 

import re
from num2words import num2words

# function to convert numbers to words
def num_to_words(text):
    
# splitting text into words with space
    after_spliting = text.split()

    for index in range(len(after_spliting)):
        if after_spliting[index].isdigit():
            after_spliting[index] = num2words(after_spliting[index])

    # joining list into string with space
    numbers_to_words = ' '.join(after_spliting)
    return numbers_to_words

def remove_extra_spaces(text):

 space_pattern = r'\s+'
 without_space = re.sub(pattern=space_pattern, repl=" ", string=text)
 return without_space

def lower_case_convertion(text):

    lower_text = text.lower()
    return lower_text

from nltk.corpus import stopwords
from nltk import word_tokenize
all_stopwords  = set(stopwords.words('english'))

def remove_stopwords(text):

    text_without_sw = []
    # tokenization
    text_tokens = word_tokenize(text)
    for word in text_tokens:
        # checking word is stopword or not
        if word not in all_stopwords:
            text_without_sw.append(word)

    # joining all tokens after removing stop words
    without_sw = ' '.join(text_without_sw)
    return without_sw


from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()

def lemmatization(text):
    # word tokenization
    tokens = word_tokenize(text)

    for index in range(len(tokens)):
     # lemma word
        lemma_word = lemma.lemmatize(tokens[index])
        tokens[index] = lemma_word

    return ' '.join(tokens)

# %% [markdown]
# ## A sample of 15 Pre-processed reviews

# %% [markdown]
# ### Assigned App1

# %%
for ind in description.index:
     description['Review'][ind]=remove_punctuation(description['Review'][ind])    
        
for ind in description.index:
     description['Review'][ind]=remove_emoji(description['Review'][ind])        
        
        
for ind in description.index:
     description['Review'][ind]=remove_special_chars(description['Review'][ind])        
        
for ind in description.index:
     description['Review'][ind]=num_to_words(description['Review'][ind])        
        
for ind in description.index:
     description['Review'][ind]=remove_extra_spaces(description['Review'][ind])
for ind in description.index:
     description['Review'][ind]=lower_case_convertion(description['Review'][ind])   
        
for ind in description.index:
     description['Review'][ind]=remove_stopwords(description['Review'][ind])  
        
for ind in description.index:
     description['Review'][ind]=lemmatization(description['Review'][ind])  
        
description.head(15)
# Out:
#           Reviewer name  \
# 0             Markus S.
# 1        Sun Thanavuthi
# 2            Kiri Kroem
# 3              OG Brawl
# 4            darith our
# 5        Heng Bunnathai
# 6            See Jo Mes
# 7      Administrator KH
# 8       stephen yeyeodu
# 9                  Andy
# 10  Sanjay Kumar Behera
# 11             Mam Maly
# 12              Kong Yi
# 13           Sophea Lim
# 14     Georgina ROBERTS
#
#                                                                                                                                                                                                                                                                                                                                               Review  \
# ...

# %% [markdown]
# ### Assigned App2

# %%
for ind in description2.index:
     description2['Review'][ind]=remove_punctuation(description2['Review'][ind])    
        
for ind in description2.index:
     description2['Review'][ind]=remove_emoji(description2['Review'][ind])        
        
        
for ind in description2.index:
     description2['Review'][ind]=remove_special_chars(description2['Review'][ind])        
        
for ind in description2.index:
     description2['Review'][ind]=num_to_words(description2['Review'][ind])        
        
for ind in description2.index:
     description2['Review'][ind]=remove_extra_spaces(description2['Review'][ind])
for ind in description2.index:
     description2['Review'][ind]=lower_case_convertion(description2['Review'][ind])   
        
for ind in description2.index:
     description2['Review'][ind]=remove_stopwords(description2['Review'][ind])        
for ind in description2.index:
     description2['Review'][ind]=lemmatization(description2['Review'][ind])  
        
description2.head(15)
# Out:
#         Reviewer name  \
# 0   Shizune Hakamichi
# 1         Chris Miles
# 2       Michael Barry
# 3        Nieves Mares
# 4           Matt Kell
# 5    Olivier Pinsolle
# 6       OneMan NoName
# 7         Uncle Snail
# 8        Chris Thomas
# 9         Green Raven
# 10       Adam Gashlin
# 11        Damian Rene
# 12         Alex Levin
# 13        Jesse Klein
# 14         Dale Royer
#
#                                                                                                                                                                                                                                                                             Review  \
# 0                                                                                                                                                                                                                                                                             work
# ...

# %% [markdown]
# ### Assigned App3

# %%
for ind in description3.index:
     description3['Review'][ind]=remove_punctuation(description3['Review'][ind])    
        
for ind in description3.index:
     description3['Review'][ind]=remove_emoji(description3['Review'][ind])        
        
        
for ind in description3.index:
     description3['Review'][ind]=remove_special_chars(description3['Review'][ind])        
        
for ind in description3.index:
     description3['Review'][ind]=num_to_words(description3['Review'][ind])        
        
for ind in description3.index:
     description3['Review'][ind]=remove_extra_spaces(description3['Review'][ind])
        
for ind in description3.index:
     description3['Review'][ind]=lower_case_convertion(description3['Review'][ind])   
        
for ind in description3.index:
     description3['Review'][ind]=remove_stopwords(description3['Review'][ind])   
        
for ind in description3.index:
     description3['Review'][ind]=lemmatization(description3['Review'][ind])  
        
description3.head(15)
# Out:
#          Reviewer name  \
# 0   Alexandre Ostrenko
# 1              Miakoda
# 2            A Douglas
# 3     Timothy Hoogland
# 4       Florian Gibala
# 5        A Google user
# 6          Peter Szabo
# 7          Landon Wark
# 8         Josh Stuckey
# 9                 Zs B
# 10           Anton Kro
# 11     Phillip Clapham
# 12     Philipp Bartels
# 13               Tom -
# 14         Ju-eng Ling
#
#                                                                                                                                                                                                                                                                Review  \
# 0                                                                                                                                                                                                               didnt work error error portal okay login software bug
# ...

# %% [markdown]
# ### Assigned App4

# %%
for ind in description4.index:
     description4['Review'][ind]=remove_punctuation(description4['Review'][ind])    
        
for ind in description4.index:
     description4['Review'][ind]=remove_emoji(description4['Review'][ind])        
        
        
for ind in description4.index:
     description4['Review'][ind]=remove_special_chars(description4['Review'][ind])        
        
for ind in description4.index:
     description4['Review'][ind]=num_to_words(description4['Review'][ind])        
        
for ind in description4.index:
     description4['Review'][ind]=remove_extra_spaces(description4['Review'][ind])
        
for ind in description4.index:
     description4['Review'][ind]=lower_case_convertion(description4['Review'][ind])   
        
for ind in description4.index:
     description4['Review'][ind]=remove_stopwords(description4['Review'][ind])   
        
for ind in description4.index:
     description4['Review'][ind]=lemmatization(description4['Review'][ind])  
        
description4.head(15)
# Out:
#               Reviewer name  \
# 0   SEDIMAR SAKILAN SUHAILI
# 1            DANNY MULEMENA
# 2            Mitiku Tilahun
# 3               Mamun Mamun
# 4         Sports Highlights
# 5              Abet Beltran
# 6        The Beshear Family
# 7         Nilushi Dinushani
# 8            Joshep Starlin
# 9              Zakey Wisdom
# 10        Nilushi Dinushani
# 11            Suleyman Shah
# 12        Iresh Chandrasena
# 13             N&R Creation
# 14          Demonstator Man
#
#                                                                                                                                                                                                                           Review  \
# 0                                                                                                                                                                  make permanent file uploaded please remove expiry date hope u
# ...

# %%
#description5.dropna(subset=['Review'])

# %% [markdown]
# ### Assigned App5

# %%
   
description5['Review'] = description5['Review'].astype(str)  

for ind in description5.index:
     description5['Review'][ind]=remove_punctuation(description5['Review'][ind])
        
for ind in description5.index:
     description5['Review'][ind]=remove_emoji(description5['Review'][ind])        
        
        
for ind in description5.index:
     description5['Review'][ind]=remove_special_chars(description5['Review'][ind])        
        
for ind in description5.index:
     description5['Review'][ind]=num_to_words(description5['Review'][ind])        
        
for ind in description5.index:
     description5['Review'][ind]=remove_extra_spaces(description5['Review'][ind])
        
for ind in description5.index:
     description5['Review'][ind]=lower_case_convertion(description5['Review'][ind])   
        
for ind in description5.index:
     description5['Review'][ind]=remove_stopwords(description5['Review'][ind])   
        
for ind in description5.index:
     description5['Review'][ind]=lemmatization(description5['Review'][ind])  
        
       
        

        
description5.head(15)
# Out:
#         Reviewer Name  \
# 0       Andrew Wright
# 1        Stijn Tintel
# 2            Auke Kok
# 3       A Google user
# 4         Luke Dashjr
# 5       Marvin Clavey
# 6       A Google user
# 7   Arniceous Maximus
# 8        Ahti Järvelä
# 9   Michael Carpenter
# 10      Tamara Jordan
# 11      A Google user
# 12             koichi
# 13   Ryonia Coruscare
# 14      A Google user
#
#                                                                                                                                                        Review  \
# 0           hate new app chat list avatar dont go away even avatar option disabled also cant turn topic name two combined make list spread really hard scroll
# 1                                                              horrible button appear long pressing network work need delete network add make thing reconnect
# ...

# %% [markdown]
# # TASK 3: SENTIMENT ANALYSIS

# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### I. Use Textblob for calculating Reviews Sentiment;

# %%
from textblob import TextBlob

# %% [markdown]
# ### Assigned app1

# %% [markdown]
# ### code snippet for textblob sentiment analysis

# %%
app1_sentiment = description[["Package name","Review"]]
polar=[]
for ind in app1_sentiment.index:
        sentence = app1_sentiment['Review'][ind]
        blob = TextBlob(sentence)
        blob.sentiment
        print(blob.sentiment)
        
        polar.append(blob.sentiment.polarity)
        
app1_sentiment["Polarity"]=polar
# Out:
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=-0.6142857142857142, subjectivity=0.6428571428571429)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05238095238095243, subjectivity=0.4261904761904761)
# Sentiment(polarity=0.175, subjectivity=0.625)
# Sentiment(polarity=-0.39583333333333337, subjectivity=0.7708333333333333)
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Sentiment(polarity=-0.19999999999999996, subjectivity=0.525)
# Sentiment(polarity=-0.09166666666666667, subjectivity=0.5178571428571429)
# Sentiment(polarity=-0.375, subjectivity=0.45)
# Sentiment(polarity=-0.05000000000000001, subjectivity=0.2555555555555556)
# Sentiment(polarity=0.0, subjectivity=0.7)
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.44166666666666665)
# Sentiment(polarity=-0.0023809523809523803, subjectivity=0.3738095238095238)
# ...

# %% [markdown]
# ###   output table

# %%
app1_sentiment.head(3000)
# Out:
#                               Package name  \
# 0                   de.chaosdorf.meteroid2
# 1                    com.wingmoney.wingpay
# 2                    com.wingmoney.wingpay
# 3                    com.wingmoney.wingpay
# 4                    com.wingmoney.wingpay
# ...                                    ...
# 2163  com.google.android.apps.walletnfcrel
# 2164  com.google.android.apps.walletnfcrel
# 2165  com.google.android.apps.walletnfcrel
# 2166  com.google.android.apps.walletnfcrel
# 2167  com.google.android.apps.walletnfcrel
#
#                                                                                                                                                                                                                                                                                                                                                                    Review  \
# ...

# %% [markdown]
# ### Assigned app2

# %% [markdown]
# ### code snippet for textblob sentiment analysis

# %%
app2_sentiment = description2[["Package name","Review"]]
polar2=[]
for ind in app2_sentiment.index:
        sentence = app2_sentiment['Review'][ind]
        blob = TextBlob(sentence)
        blob.sentiment
        print(blob.sentiment)
        
        polar2.append(blob.sentiment.polarity)
        
app2_sentiment["Polarity"]=polar2
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.305, subjectivity=0.6077777777777778)
# Sentiment(polarity=0.1708333333333333, subjectivity=0.4000000000000001)
# Sentiment(polarity=0.35, subjectivity=0.65)
# Sentiment(polarity=0.225, subjectivity=0.5125)
# Sentiment(polarity=0.175, subjectivity=0.725)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.2, subjectivity=0.575)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.3, subjectivity=0.35)
# Sentiment(polarity=0.43333333333333335, subjectivity=0.6944444444444443)
# Sentiment(polarity=0.2380952380952381, subjectivity=0.45238095238095233)
# Sentiment(polarity=0.00833333333333334, subjectivity=0.3)
# Sentiment(polarity=0.4, subjectivity=0.5535714285714286)
# Sentiment(polarity=0.5666666666666667, subjectivity=0.55)
# Sentiment(polarity=0.375, subjectivity=0.65)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=1.0, subjectivity=1.0)
# ...

# %% [markdown]
# ### output table

# %%
app2_sentiment.head(3000)
# Out:
#                         Package name  \
# 0     com.flashsphere.rainwaveplayer
# 1     com.flashsphere.rainwaveplayer
# 2     com.flashsphere.rainwaveplayer
# 3     com.flashsphere.rainwaveplayer
# 4     com.flashsphere.rainwaveplayer
# ...                              ...
# 1095                  com.ilv.vradio
# 1096                  com.ilv.vradio
# 1097                  com.ilv.vradio
# 1098                  com.ilv.vradio
# 1099                  com.ilv.vradio
#
#                                                                                                                                                                                                                                                                               Review  \
# ...

# %% [markdown]
# ### Assigned app3

# %% [markdown]
# ### code snippet for textblob sentiment analysis

# %%
app3_sentiment = description3[["Package name","Review"]]
polar3=[]
for ind in app3_sentiment.index:
        sentence = app3_sentiment['Review'][ind]
        blob = TextBlob(sentence)
        blob.sentiment
        print(blob.sentiment)
        
        polar3.append(blob.sentiment.polarity)
        
app3_sentiment["Polarity"]=polar3
# Out:
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=-0.5, subjectivity=0.2)
# Sentiment(polarity=-0.07142857142857144, subjectivity=0.5976190476190476)
# Sentiment(polarity=0.5, subjectivity=0.9)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=-0.5, subjectivity=0.3)
# Sentiment(polarity=0.06904761904761905, subjectivity=0.21666666666666665)
# Sentiment(polarity=0.5, subjectivity=0.9)
# Sentiment(polarity=-0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.6, subjectivity=1.0)
# Sentiment(polarity=0.26666666666666666, subjectivity=0.375)
# Sentiment(polarity=0.0576530612244898, subjectivity=0.37040816326530607)
# Sentiment(polarity=-0.019999999999999997, subjectivity=0.5599999999999999)
# Sentiment(polarity=-0.03703703703703702, subjectivity=0.4026455026455027)
# Sentiment(polarity=0.3041666666666667, subjectivity=0.6333333333333333)
# Sentiment(polarity=0.21666666666666665, subjectivity=0.2583333333333333)
# ...

# %% [markdown]
# ### output table

# %%
app3_sentiment.head(3000)
# Out:
#                       Package name  \
# 0     it.niedermann.owncloud.notes
# 1     it.niedermann.owncloud.notes
# 2     it.niedermann.owncloud.notes
# 3     it.niedermann.owncloud.notes
# 4     it.niedermann.owncloud.notes
# ...                            ...
# 1570  com.microsoft.office.onenote
# 1571  com.microsoft.office.onenote
# 1572  com.microsoft.office.onenote
# 1573  com.microsoft.office.onenote
# 1574  com.microsoft.office.onenote
#
#                                                                                                                                       Review  \
# 0                                                                                      didnt work error error portal okay login software bug
# 1                              stopped syncing removed account readded go uninstalled reinstalled go couldnt find support app became useless
# ...

# %% [markdown]
# ### Assigned app4

# %% [markdown]
# ### code snippet for textblob sentiment analysis

# %%
app4_sentiment = description4[["Package name","Review"]]
polar4=[]
for ind in app4_sentiment.index:
        sentence = app4_sentiment['Review'][ind]
        blob = TextBlob(sentence)
        blob.sentiment
        print(blob.sentiment)
        
        polar4.append(blob.sentiment.polarity)
        
app4_sentiment["Polarity"]=polar4
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3337662337662337, subjectivity=0.5101731601731602)
# Sentiment(polarity=0.6388888888888888, subjectivity=0.7166666666666667)
# Sentiment(polarity=0.38749999999999996, subjectivity=0.725)
# Sentiment(polarity=0.5166666666666667, subjectivity=0.5)
# Sentiment(polarity=0.7371428571428572, subjectivity=0.5628571428571428)
# Sentiment(polarity=0.35, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.24444444444444446, subjectivity=0.3968253968253968)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.3, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...

# %% [markdown]
# ### output table

# %%
app4_sentiment.head(3000)
# Out:
#                            Package name  \
# 0     com.fileupload.filesharing.upfile
# 1     com.fileupload.filesharing.upfile
# 2     com.fileupload.filesharing.upfile
# 3     com.fileupload.filesharing.upfile
# 4     com.fileupload.filesharing.upfile
# ...                                 ...
# 1825           mega.privacy.android.app
# 1826           mega.privacy.android.app
# 1827           mega.privacy.android.app
# 1828           mega.privacy.android.app
# 1829           mega.privacy.android.app
#
#                                                                           Review  \
# 0                  make permanent file uploaded please remove expiry date hope u
# 1                                                                 failing upload
# 2                                                                           good
# 3                                                                       badd dog
# ...

# %% [markdown]
# ### Assigned app5

# %% [markdown]
# ### code snippet for textblob sentiment analysis

# %%
app5_sentiment = description5[["Package name","Review"]]
polar5=[]
for ind in app5_sentiment.index:
        sentence = app5_sentiment['Review'][ind]
        blob = TextBlob(sentence)
        blob.sentiment
        print(blob.sentiment)
        
        polar5.append(blob.sentiment.polarity)
        
app5_sentiment["Polarity"]=polar5
# Out:
# Sentiment(polarity=-0.2888257575757576, subjectivity=0.5490530303030303)
# Sentiment(polarity=-0.525, subjectivity=0.7)
# Sentiment(polarity=-0.0045454545454545565, subjectivity=0.6681818181818183)
# Sentiment(polarity=-0.26666666666666666, subjectivity=0.6)
# Sentiment(polarity=0.024999999999999994, subjectivity=0.575)
# Sentiment(polarity=-0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.07857142857142857, subjectivity=0.3991071428571429)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.275, subjectivity=0.7)
# Sentiment(polarity=-0.5, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5083333333333333, subjectivity=0.7)
# ...

# %% [markdown]
# ### output table

# %%
app5_sentiment.head(3000)
# Out:
#                       Package name  \
# 0     com.iskrembilen.quasseldroid
# 1     com.iskrembilen.quasseldroid
# 2     com.iskrembilen.quasseldroid
# 3     com.iskrembilen.quasseldroid
# 4     com.iskrembilen.quasseldroid
# ...                            ...
# 1325                  com.androirc
# 1326                  com.androirc
# 1327                  com.androirc
# 1328                  com.androirc
# 1329                  com.androirc
#
#                                                                                                                                                  Review  \
# 0     hate new app chat list avatar dont go away even avatar option disabled also cant turn topic name two combined make list spread really hard scroll
# 1                                                        horrible button appear long pressing network work need delete network add make thing reconnect
# ...

# %% [markdown]
# ### III. Use Vader for calculating Reviews Sentiment;

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\gilla\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Assigned App 1

# %% [markdown]
# ### Code snippet for Vader Sentiment Analysis

# %%
app1_sentiment_vader = description[["Package name","Review"]]

app1_sentiment_vader['scores'] = app1_sentiment_vader['Review'].apply(lambda review: sid.polarity_scores(review))

app1_sentiment_vader.head()
# Out:
#              Package name  \
# 0  de.chaosdorf.meteroid2
# 1   com.wingmoney.wingpay
# 2   com.wingmoney.wingpay
# 3   com.wingmoney.wingpay
# 4   com.wingmoney.wingpay
#
#                                                                                                                                   Review  \
# 0                                                                                                                              excellent
# 1  worst worst app always say internet connection wonder people rate five star bad app cant even open app reinstall wasted money bad bad
# 2                                         always error without inform correct pop message whatever happens say check internet connection
# 3                                              keep show error message please check internet connection internet problem please fix asap
# ...

# %% [markdown]
# ### Output Table

# %%
#Now will call out compound which is a polarity as a separate column and all values greater than zeroes will be considered 
#a positive review and all values less than zero would be considered as a negative review.

app1_sentiment_vader['Polarity']  = app1_sentiment_vader['scores'].apply(lambda score_dict: score_dict['compound'])
app1_sentiment_nvader = app1_sentiment_vader[["Package name","Review","Polarity"]]
app1_sentiment_nvader.head(3000)
# Out:
#                               Package name  \
# 0                   de.chaosdorf.meteroid2
# 1                    com.wingmoney.wingpay
# 2                    com.wingmoney.wingpay
# 3                    com.wingmoney.wingpay
# 4                    com.wingmoney.wingpay
# ...                                    ...
# 2163  com.google.android.apps.walletnfcrel
# 2164  com.google.android.apps.walletnfcrel
# 2165  com.google.android.apps.walletnfcrel
# 2166  com.google.android.apps.walletnfcrel
# 2167  com.google.android.apps.walletnfcrel
#
#                                                                                                                                                                                                                                                                                                                                                                    Review  \
# ...

# %% [markdown]
# ### Assigned App 2

# %% [markdown]
# ### Code snippet for Vader Sentiment Analysis

# %%
app2_sentiment_vader = description2[["Package name","Review"]]

app2_sentiment_vader['scores'] = app2_sentiment_vader['Review'].apply(lambda review: sid.polarity_scores(review))

app2_sentiment_vader.head()
# Out:
#                      Package name  \
# 0  com.flashsphere.rainwaveplayer
# 1  com.flashsphere.rainwaveplayer
# 2  com.flashsphere.rainwaveplayer
# 3  com.flashsphere.rainwaveplayer
# 4  com.flashsphere.rainwaveplayer
#
#                                                                                                                                                                                                                                                                            Review  \
# 0                                                                                                                                                                                                                                                                            work
# ...

# %% [markdown]
# # Output table.

# %%
app2_sentiment_vader['Polarity']  = app2_sentiment_vader['scores'].apply(lambda score_dict: score_dict['compound'])
app2_sentiment_nvader = app2_sentiment_vader[["Package name","Review","Polarity"]]
app2_sentiment_nvader.head(3000)
# Out:
#                         Package name  \
# 0     com.flashsphere.rainwaveplayer
# 1     com.flashsphere.rainwaveplayer
# 2     com.flashsphere.rainwaveplayer
# 3     com.flashsphere.rainwaveplayer
# 4     com.flashsphere.rainwaveplayer
# ...                              ...
# 1095                  com.ilv.vradio
# 1096                  com.ilv.vradio
# 1097                  com.ilv.vradio
# 1098                  com.ilv.vradio
# 1099                  com.ilv.vradio
#
#                                                                                                                                                                                                                                                                               Review  \
# ...

# %% [markdown]
# ### Assigned App 3

# %% [markdown]
# ### Code snippet for Vader Sentiment Analysis

# %%
app3_sentiment_vader = description3[["Package name","Review"]]

app3_sentiment_vader['scores'] = app3_sentiment_vader['Review'].apply(lambda review: sid.polarity_scores(review))

app3_sentiment_vader.head()
# Out:
#                    Package name  \
# 0  it.niedermann.owncloud.notes
# 1  it.niedermann.owncloud.notes
# 2  it.niedermann.owncloud.notes
# 3  it.niedermann.owncloud.notes
# 4  it.niedermann.owncloud.notes
#
#                                                                                                                         Review  \
# 0                                                                        didnt work error error portal okay login software bug
# 1                stopped syncing removed account readded go uninstalled reinstalled go couldnt find support app became useless
# 2  even work error immediately thrown username andor password wrong right im self hosting nextcloud instance issue simply work
# 3                                                                   doesnt work latest nextcloud update getting file api error
# 4                                                                        sadly used self signed certificate please add support
#
# ...

# %% [markdown]
# ### Output Table

# %%
app3_sentiment_vader['Polarity']  = app3_sentiment_vader['scores'].apply(lambda score_dict: score_dict['compound'])
app3_sentiment_nvader = app3_sentiment_vader[["Package name","Review","Polarity"]]
app3_sentiment_nvader.head(3000)
# Out:
#                       Package name  \
# 0     it.niedermann.owncloud.notes
# 1     it.niedermann.owncloud.notes
# 2     it.niedermann.owncloud.notes
# 3     it.niedermann.owncloud.notes
# 4     it.niedermann.owncloud.notes
# ...                            ...
# 1570  com.microsoft.office.onenote
# 1571  com.microsoft.office.onenote
# 1572  com.microsoft.office.onenote
# 1573  com.microsoft.office.onenote
# 1574  com.microsoft.office.onenote
#
#                                                                                                                                       Review  \
# 0                                                                                      didnt work error error portal okay login software bug
# 1                              stopped syncing removed account readded go uninstalled reinstalled go couldnt find support app became useless
# ...

# %% [markdown]
# ### Assigned App 4

# %% [markdown]
# ### Code snippet for Vader Sentiment Analysis

# %%
app4_sentiment_vader = description4[["Package name","Review"]]

app4_sentiment_vader['scores'] = app4_sentiment_vader['Review'].apply(lambda review: sid.polarity_scores(review))

app4_sentiment_vader.head()
# Out:
#                         Package name  \
# 0  com.fileupload.filesharing.upfile
# 1  com.fileupload.filesharing.upfile
# 2  com.fileupload.filesharing.upfile
# 3  com.fileupload.filesharing.upfile
# 4  com.fileupload.filesharing.upfile
#
#                                                           Review  \
# 0  make permanent file uploaded please remove expiry date hope u
# 1                                                 failing upload
# 2                                                           good
# 3                                                       badd dog
# 4                        deserve three star bcoz z specific tube
#
#                                                           scores
# 0   {'neg': 0.0, 'neu': 0.574, 'pos': 0.426, 'compound': 0.6369}
# 1  {'neg': 0.767, 'neu': 0.233, 'pos': 0.0, 'compound': -0.5106}
# 2       {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404}
# 3          {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ...

# %% [markdown]
# ### Output table

# %%
app4_sentiment_vader['Polarity']  = app4_sentiment_vader['scores'].apply(lambda score_dict: score_dict['compound'])
app4_sentiment_nvader = app4_sentiment_vader[["Package name","Review","Polarity"]]
app4_sentiment_nvader.head(3000)
# Out:
#                            Package name  \
# 0     com.fileupload.filesharing.upfile
# 1     com.fileupload.filesharing.upfile
# 2     com.fileupload.filesharing.upfile
# 3     com.fileupload.filesharing.upfile
# 4     com.fileupload.filesharing.upfile
# ...                                 ...
# 1825           mega.privacy.android.app
# 1826           mega.privacy.android.app
# 1827           mega.privacy.android.app
# 1828           mega.privacy.android.app
# 1829           mega.privacy.android.app
#
#                                                                           Review  \
# 0                  make permanent file uploaded please remove expiry date hope u
# 1                                                                 failing upload
# 2                                                                           good
# 3                                                                       badd dog
# ...

# %% [markdown]
# ### Assigned App 5

# %% [markdown]
# ### Code snippet for Vader Sentiment Analysis

# %%
app5_sentiment_vader = description5[["Package name","Review"]]

app5_sentiment_vader['scores'] = app5_sentiment_vader['Review'].apply(lambda review: sid.polarity_scores(review))

app5_sentiment_vader.head()
# Out:
#                    Package name  \
# 0  com.iskrembilen.quasseldroid
# 1  com.iskrembilen.quasseldroid
# 2  com.iskrembilen.quasseldroid
# 3  com.iskrembilen.quasseldroid
# 4  com.iskrembilen.quasseldroid
#
#                                                                                                                                               Review  \
# 0  hate new app chat list avatar dont go away even avatar option disabled also cant turn topic name two combined make list spread really hard scroll
# 1                                                     horrible button appear long pressing network work need delete network add make thing reconnect
# 2                                                            really disappointed new version doesnt highlight channel severity hinders effective use
# 3                                                                                                 somehow ui got even worse ill sideload old version
# ...

# %% [markdown]
# ### Output Table

# %%
app5_sentiment_vader['Polarity']  = app5_sentiment_vader['scores'].apply(lambda score_dict: score_dict['compound'])
app5_sentiment_nvader = app5_sentiment_vader[["Package name","Review","Polarity"]]
app5_sentiment_nvader.head(3000)
# Out:
#                       Package name  \
# 0     com.iskrembilen.quasseldroid
# 1     com.iskrembilen.quasseldroid
# 2     com.iskrembilen.quasseldroid
# 3     com.iskrembilen.quasseldroid
# 4     com.iskrembilen.quasseldroid
# ...                            ...
# 1325                  com.androirc
# 1326                  com.androirc
# 1327                  com.androirc
# 1328                  com.androirc
# 1329                  com.androirc
#
#                                                                                                                                                  Review  \
# 0     hate new app chat list avatar dont go away even avatar option disabled also cant turn topic name two combined make list spread really hard scroll
# 1                                                        horrible button appear long pressing network work need delete network add make thing reconnect
# ...

# %% [markdown]
# ## V. Comparison of sentiments retrieved by Textblob and Vader

# %% [markdown]
# Sentiments retrieved by Textblob and Vader are compared with each other by finding the sentiment type of each review.
# Polarity is a float that lies between [-1,1], -1 indicates negative sentiment, 0 indicates neutral sentiments, and +1 indicates positive sentiments. Sentiment type of each review is found from both Textblob and Vader analysis. Then total count of each sentiment type of each type of analysis is calculated. Polarity and Sentiment type of each review for both Textblob and Vader analysis is shown on a table for comparison. Then total count of sentiment type of each type of analysis is plotted on a graph which further helps in comparison.
#
#
# Similarity and difference is interpreted from the total count of positive, neutral, and negative reviews and also from the graphs. Also, manual inspection from output table of polarity and sentiment type of each review of each type of  analysis helps to interpret the similarity and difference.
#
# After comparison and interpretation, it is found that both libraries output relatively similar results, however VADER looks to pick up more of the negative tone from the reviews, which TextBlob missed out on.
# Textblob ignores the words that it doesn’t know, it considers words and phrases that it can assign polarity to and averages to get the final score.

# %% [markdown]
# # Assigned App 1

# %% [markdown]
# ### Textblob

# %%
#app1_sentiment['Sentiment_Type'] = app1_sentiment['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app1_sentiment.head()

app1_sentiment['Sentiment_Type']=''
app1_sentiment.loc[app1_sentiment.Polarity>0,'Sentiment_Type']='POSITIVE'
app1_sentiment.loc[app1_sentiment.Polarity==0,'Sentiment_Type']='NEUTRAL'
app1_sentiment.loc[app1_sentiment.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app1_sentiment['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    1325
# NEGATIVE     428
# NEUTRAL      415
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Vader

# %%
#app1_sentiment_nvader['comp_score'] = app1_sentiment_nvader['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app1_sentiment_nvader.head()
app1_sentiment_nvader['Sentiment_Type']=''
app1_sentiment_nvader.loc[app1_sentiment_nvader.Polarity>0,'Sentiment_Type']='POSITIVE'
app1_sentiment_nvader.loc[app1_sentiment_nvader.Polarity==0,'Sentiment_Type']='NEUTRAL'
app1_sentiment_nvader.loc[app1_sentiment_nvader.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app1_sentiment_nvader['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    1367
# NEGATIVE     541
# NEUTRAL      260
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Output Table containing containining polarity and Sentiment type of both textblob and vader for comparison

# %%
app1_sentiment_comparison = app1_sentiment_nvader[["Package name","Review"]]
app1_sentiment_comparison['textblob_polarity']= app1_sentiment["Polarity"]
app1_sentiment_comparison['textblob_Sentiment_Type']= app1_sentiment["Sentiment_Type"]
app1_sentiment_comparison['vader_polarity']= app1_sentiment_nvader["Polarity"]
app1_sentiment_comparison['vader_Sentiment_Type']= app1_sentiment_nvader["Sentiment_Type"]
app1_sentiment_comparison.head(3000)
# Out:
#                               Package name  \
# 0                   de.chaosdorf.meteroid2
# 1                    com.wingmoney.wingpay
# 2                    com.wingmoney.wingpay
# 3                    com.wingmoney.wingpay
# 4                    com.wingmoney.wingpay
# ...                                    ...
# 2163  com.google.android.apps.walletnfcrel
# 2164  com.google.android.apps.walletnfcrel
# 2165  com.google.android.apps.walletnfcrel
# 2166  com.google.android.apps.walletnfcrel
# 2167  com.google.android.apps.walletnfcrel
#
#                                                                                                                                                                                                                                                                                                                                                                    Review  \
# ...

# %%
app1_sentiment.Sentiment_Type.value_counts().plot(kind='bar',title="Textblob Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Textblob Sentiment Analysis'}>

# %%
app1_sentiment_nvader.Sentiment_Type.value_counts().plot(kind='bar',title="Vader Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Vader Sentiment Analysis'}>

# %% [markdown]
# ### Assigned App 2

# %% [markdown]
# ### Textblob

# %%
#app2_sentiment['comp_score'] = app2_sentiment['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app2_sentiment.head()

app2_sentiment['Sentiment_Type']=''
app2_sentiment.loc[app2_sentiment.Polarity>0,'Sentiment_Type']='POSITIVE'
app2_sentiment.loc[app2_sentiment.Polarity==0,'Sentiment_Type']='NEUTRAL'
app2_sentiment.loc[app2_sentiment.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app2_sentiment['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    763
# NEUTRAL     244
# NEGATIVE     93
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Vader

# %%
#app2_sentiment_nvader['comp_score'] = app2_sentiment_nvader['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')

#app2_sentiment_nvader.head()

app2_sentiment_nvader['Sentiment_Type']=''
app2_sentiment_nvader.loc[app2_sentiment_nvader.Polarity>0,'Sentiment_Type']='POSITIVE'
app2_sentiment_nvader.loc[app2_sentiment_nvader.Polarity==0,'Sentiment_Type']='NEUTRAL'
app2_sentiment_nvader.loc[app2_sentiment_nvader.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app2_sentiment_nvader['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    780
# NEUTRAL     178
# NEGATIVE    142
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Output Table containing polarity and Sentiment type of both textblob and vader for comparison¶

# %%
app2_sentiment_comparison = app2_sentiment_nvader[["Package name","Review"]]
app2_sentiment_comparison['textblob_polarity']= app2_sentiment["Polarity"]
app2_sentiment_comparison['textblob_Sentiment_Type']= app2_sentiment["Sentiment_Type"]
app2_sentiment_comparison['vader_polarity']= app2_sentiment_nvader["Polarity"]
app2_sentiment_comparison['vader_Sentiment_Type']= app2_sentiment_nvader["Sentiment_Type"]
app2_sentiment_comparison.head(3000)
# Out:
#                         Package name  \
# 0     com.flashsphere.rainwaveplayer
# 1     com.flashsphere.rainwaveplayer
# 2     com.flashsphere.rainwaveplayer
# 3     com.flashsphere.rainwaveplayer
# 4     com.flashsphere.rainwaveplayer
# ...                              ...
# 1095                  com.ilv.vradio
# 1096                  com.ilv.vradio
# 1097                  com.ilv.vradio
# 1098                  com.ilv.vradio
# 1099                  com.ilv.vradio
#
#                                                                                                                                                                                                                                                                               Review  \
# ...

# %%
app2_sentiment.Sentiment_Type.value_counts().plot(kind='bar',title="Textblob Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Textblob Sentiment Analysis'}>

# %%
app2_sentiment_nvader.Sentiment_Type.value_counts().plot(kind='bar',title="Vader Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Vader Sentiment Analysis'}>

# %% [markdown]
# ### Assigned App 3

# %% [markdown]
# ### Textblob

# %%
#app3_sentiment['comp_score'] = app3_sentiment['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app3_sentiment.head()

app3_sentiment['Sentiment_Type']=''
app3_sentiment.loc[app3_sentiment.Polarity>0,'Sentiment_Type']='POSITIVE'
app3_sentiment.loc[app3_sentiment.Polarity==0,'Sentiment_Type']='NEUTRAL'
app3_sentiment.loc[app3_sentiment.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app3_sentiment['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    1163
# NEGATIVE     251
# NEUTRAL      161
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Vader

# %%
#app3_sentiment_nvader['comp_score'] = app3_sentiment_nvader['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app3_sentiment_nvader.head()

app3_sentiment_nvader['Sentiment_Type']=''
app3_sentiment_nvader.loc[app3_sentiment_nvader.Polarity>0,'Sentiment_Type']='POSITIVE'
app3_sentiment_nvader.loc[app3_sentiment_nvader.Polarity==0,'Sentiment_Type']='NEUTRAL'
app3_sentiment_nvader.loc[app3_sentiment_nvader.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app3_sentiment_nvader['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    1214
# NEGATIVE     253
# NEUTRAL      108
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Output Table containing polarity and Sentiment type of both textblob and vader for comparison¶

# %%
app3_sentiment_comparison = app3_sentiment_nvader[["Package name","Review"]]
app3_sentiment_comparison['textblob_polarity']= app3_sentiment["Polarity"]
app3_sentiment_comparison['textblob_Sentiment_Type']= app3_sentiment["Sentiment_Type"]
app3_sentiment_comparison['vader_polarity']= app3_sentiment_nvader["Polarity"]
app3_sentiment_comparison['vader_Sentiment_Type']= app3_sentiment_nvader["Sentiment_Type"]
app3_sentiment_comparison.head(3000)
# Out:
#                       Package name  \
# 0     it.niedermann.owncloud.notes
# 1     it.niedermann.owncloud.notes
# 2     it.niedermann.owncloud.notes
# 3     it.niedermann.owncloud.notes
# 4     it.niedermann.owncloud.notes
# ...                            ...
# 1570  com.microsoft.office.onenote
# 1571  com.microsoft.office.onenote
# 1572  com.microsoft.office.onenote
# 1573  com.microsoft.office.onenote
# 1574  com.microsoft.office.onenote
#
#                                                                                                                                       Review  \
# 0                                                                                      didnt work error error portal okay login software bug
# 1                              stopped syncing removed account readded go uninstalled reinstalled go couldnt find support app became useless
# ...

# %%
app3_sentiment.Sentiment_Type.value_counts().plot(kind='bar',title="Textblob Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Textblob Sentiment Analysis'}>

# %%
app3_sentiment_nvader.Sentiment_Type.value_counts().plot(kind='bar',title="Vader Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Vader Sentiment Analysis'}>

# %% [markdown]
# ### Assigned App 4

# %% [markdown]
# ### Textblob

# %%
#app4_sentiment['comp_score'] = app4_sentiment['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app4_sentiment.head()

app4_sentiment['Sentiment_Type']=''
app4_sentiment.loc[app4_sentiment.Polarity>0,'Sentiment_Type']='POSITIVE'
app4_sentiment.loc[app4_sentiment.Polarity==0,'Sentiment_Type']='NEUTRAL'
app4_sentiment.loc[app4_sentiment.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app4_sentiment['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    1182
# NEGATIVE     364
# NEUTRAL      284
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Vader

# %%
#app4_sentiment_nvader['comp_score'] = app4_sentiment_nvader['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app4_sentiment_nvader.head()

app4_sentiment_nvader['Sentiment_Type']=''
app4_sentiment_nvader.loc[app4_sentiment_nvader.Polarity>0,'Sentiment_Type']='POSITIVE'
app4_sentiment_nvader.loc[app4_sentiment_nvader.Polarity==0,'Sentiment_Type']='NEUTRAL'
app4_sentiment_nvader.loc[app4_sentiment_nvader.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app4_sentiment_nvader['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    1216
# NEGATIVE     461
# NEUTRAL      153
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Output Table containing polarity and Sentiment type of both textblob and vader for comparison¶

# %%
app4_sentiment_comparison = app4_sentiment_nvader[["Package name","Review"]]
app4_sentiment_comparison['textblob_polarity']= app4_sentiment["Polarity"]
app4_sentiment_comparison['textblob_Sentiment_Type']= app4_sentiment["Sentiment_Type"]
app4_sentiment_comparison['vader_polarity']= app4_sentiment_nvader["Polarity"]
app4_sentiment_comparison['vader_Sentiment_Type']= app4_sentiment_nvader["Sentiment_Type"]
app4_sentiment_comparison.head(3000)
# Out:
#                            Package name  \
# 0     com.fileupload.filesharing.upfile
# 1     com.fileupload.filesharing.upfile
# 2     com.fileupload.filesharing.upfile
# 3     com.fileupload.filesharing.upfile
# 4     com.fileupload.filesharing.upfile
# ...                                 ...
# 1825           mega.privacy.android.app
# 1826           mega.privacy.android.app
# 1827           mega.privacy.android.app
# 1828           mega.privacy.android.app
# 1829           mega.privacy.android.app
#
#                                                                           Review  \
# 0                  make permanent file uploaded please remove expiry date hope u
# 1                                                                 failing upload
# 2                                                                           good
# 3                                                                       badd dog
# ...

# %%
app4_sentiment.Sentiment_Type.value_counts().plot(kind='bar',title="Textblob Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Textblob Sentiment Analysis'}>

# %%
app4_sentiment_nvader.Sentiment_Type.value_counts().plot(kind='bar',title="Vader Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Vader Sentiment Analysis'}>

# %% [markdown]
# ### Assigned App 5

# %% [markdown]
# ### Textblob

# %%
#app5_sentiment['comp_score'] = app5_sentiment['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app5_sentiment.head()

app5_sentiment['Sentiment_Type']=''
app5_sentiment.loc[app5_sentiment.Polarity>0,'Sentiment_Type']='POSITIVE'
app5_sentiment.loc[app5_sentiment.Polarity==0,'Sentiment_Type']='NEUTRAL'
app5_sentiment.loc[app5_sentiment.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app5_sentiment['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    755
# NEUTRAL     388
# NEGATIVE    187
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Vader

# %%
#app5_sentiment_nvader['comp_score'] = app5_sentiment_nvader['Polarity'].apply(lambda c: 'pos' if c >=0 else 'neg')
#app5_sentiment_nvader.head()

app5_sentiment_nvader['Sentiment_Type']=''
app5_sentiment_nvader.loc[app5_sentiment_nvader.Polarity>0,'Sentiment_Type']='POSITIVE'
app5_sentiment_nvader.loc[app5_sentiment_nvader.Polarity==0,'Sentiment_Type']='NEUTRAL'
app5_sentiment_nvader.loc[app5_sentiment_nvader.Polarity<0,'Sentiment_Type']='NEGATIVE'

# %%
app5_sentiment_nvader['Sentiment_Type'].value_counts()
# Out:
# POSITIVE    833
# NEGATIVE    249
# NEUTRAL     248
# Name: Sentiment_Type, dtype: int64

# %% [markdown]
# ### Output Table containing polarity and Sentiment type of both textblob and vader for comparison¶

# %%
app5_sentiment_comparison = app5_sentiment_nvader[["Package name","Review"]]
app5_sentiment_comparison['textblob_polarity']= app5_sentiment["Polarity"]
app5_sentiment_comparison['textblob_Sentiment_Type']= app5_sentiment["Sentiment_Type"]
app5_sentiment_comparison['vader_polarity']= app5_sentiment_nvader["Polarity"]
app5_sentiment_comparison['vader_Sentiment_Type']= app5_sentiment_nvader["Sentiment_Type"]
app5_sentiment_comparison.head(3000)
# Out:
#                       Package name  \
# 0     com.iskrembilen.quasseldroid
# 1     com.iskrembilen.quasseldroid
# 2     com.iskrembilen.quasseldroid
# 3     com.iskrembilen.quasseldroid
# 4     com.iskrembilen.quasseldroid
# ...                            ...
# 1325                  com.androirc
# 1326                  com.androirc
# 1327                  com.androirc
# 1328                  com.androirc
# 1329                  com.androirc
#
#                                                                                                                                                  Review  \
# 0     hate new app chat list avatar dont go away even avatar option disabled also cant turn topic name two combined make list spread really hard scroll
# 1                                                        horrible button appear long pressing network work need delete network add make thing reconnect
# ...

# %%
app5_sentiment.Sentiment_Type.value_counts().plot(kind='bar',title="Textblob Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Textblob Sentiment Analysis'}>

# %%
app5_sentiment_nvader.Sentiment_Type.value_counts().plot(kind='bar',title="Vader Sentiment Analysis")
# Out:
# <AxesSubplot:title={'center':'Vader Sentiment Analysis'}>

# %% [markdown]
# From my tests, VADER seems to work better with things like slang, emojis, etc — whereas TextBlob performs strongly with more formal language usage. VADER not only tells the lexicon is positive, negative, or neutral, it also tells how positive, negative, or neutral a sentence is. VADER gave the correct output with some of the problematic sentences and executed.
# The output brought me to the conclusion that TextBlob was struggling with negative sentences, particularly negations.
# VADER outperforms TextBlob when it comes to negative polarity detection. We can conclude that VADER does better sentiment analysis when it comes to negative polarity detection. As a result, VADER is the best option for review analysis of my apps.

# %% [markdown]
# # TASK 4: TOPIC MODELING Using LDA

# %% [markdown]
# ## I. Chosen Assigned App: Quasseldroid

# %% [markdown]
# ## II. From its reviews, extract minimum of 10 LDA topics each being described by at least 7 Words

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_colwidth',8000)

description_quas = pd.read_csv("quasseldroidtask4.csv")
#description_quas.head(1000)

# %%
import nltk
from nltk.corpus import stopwords  #stopwords
from nltk.stem import WordNetLemmatizer  
from sklearn.feature_extraction.text import TfidfVectorizer
stop_words=set(nltk.corpus.stopwords.words('english'))

# %%
description_quas['Review'] = description_quas['Review'].astype(str)  

for ind in description_quas.index:
     description_quas['Review'][ind]=remove_punctuation(description_quas['Review'][ind])
        
for ind in description_quas.index:
     description_quas['Review'][ind]=remove_emoji(description_quas['Review'][ind])        
        
        
for ind in description_quas.index:
     description_quas['Review'][ind]=remove_special_chars(description_quas['Review'][ind])        
        
for ind in description_quas.index:
     description_quas['Review'][ind]=num_to_words(description_quas['Review'][ind])        
        
for ind in description_quas.index:
     description_quas['Review'][ind]=remove_extra_spaces(description_quas['Review'][ind])
        
for ind in description_quas.index:
     description_quas['Review'][ind]=lower_case_convertion(description_quas['Review'][ind])   
        
for ind in description_quas.index:
     description_quas['Review'][ind]=remove_stopwords(description_quas['Review'][ind])   
        
for ind in description_quas.index:
     description_quas['Review'][ind]=lemmatization(description_quas['Review'][ind])  
        
       
        

        
#description5.head(15)

# %%
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000)
vect_text=vect.fit_transform(description_quas['Review'])

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=10,
learning_method='online',random_state=42,max_iter=1) 
lda_top=lda_model.fit_transform(vect_text)

# %%
print("Assigned app Quasseldroid: ")
for i,topic in enumerate(lda_top[0]):
  print("Topic ",i,": ",topic*100,"%")
# Out:
# Assigned app Quasseldroid:
# Topic  0 :  1.7723879720907114 %
# Topic  1 :  1.7723634494783198 %
# Topic  2 :  1.772384378064168 %
# Topic  3 :  1.772346160952314 %
# Topic  4 :  84.04846865574191 %
# Topic  5 :  1.7726163973737317 %
# Topic  6 :  1.7723745433254963 %
# Topic  7 :  1.772337205965189 %
# Topic  8 :  1.7723441988451962 %
# Topic  9 :  1.7723770381629527 %

# %%
vocab = vect.get_feature_names()
for i, comp in enumerate(lda_model.components_):
     vocab_comp = zip(vocab, comp)
     sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
     print("\nTopic "+str(i)+": ")
     for t in sorted_words:
            print(t[0],end=" ")
            #print("\n")
# Out:
# Topic 0:
# thanks outside see beta working disconnecting bad desktop quassel stay
# Topic 1:
# work expected exactly look pretty effort usable well destined already
# Topic 2:
# brilliant app justworks changing reconnect perfectly nan major parenthesis constantly
# Topic 3:
# need dark close button called also one version prefer quassel
# Topic 4:
# migrating say custom netbook regex highlight thing tin miss phone
# Topic 5:
# quassel thankskeep update better even coming great core awesome effortlessly
# Topic 6:
# great work irc client move nicely best core far option
# Topic 7:
# realy earlier improvement two version looking galaxy nice thirty hundred
# Topic 8:
# love thanks irc whatever best solution device problem ui able
# Topic 9:
# moto nine working eighty really droid beta perfect well galaxy

# %% [markdown]
# ### III. How does these review topics (i.e. summarized user feedback) relate to the software features (functionalities) you extracted from app description in Assignment 2 (manual) and/or Assignment 3 (automated bi-grams/tri-grams)?

# %% [markdown]
# ##### Manually extracted features:

# %% [markdown]
# Chat comfortably, REQUIRES A QUASSEL CORE, Use IRC on the go, Always have your entire chat history available, Be notified when someone messages you, Get profile pictures, a beautiful UI based on Material Design

# %% [markdown]
# ##### Bi-grams

# %% [markdown]
# [(chat, comfortably), (comfortably, everywhere), (everywhere, requires), (requires, quassel), (quassel, core), (core, work), (work, standalone), (standalone, irc), (irc, client), (client, use), (use, irc), (irc, go), (go, thanks), (thanks, quassel), (quassel, core), (core, never), (never, miss), (miss, anything), (anything, always), (always, entire), (entire, chat), (chat, history), (history, available), (available, scroll), (scroll, load), (load, older), (older, message), (message, core), (core, keep), (keep, notified), (notified, someone), (someone, message), (message, even), (even, connection), (connection, meantime), (meantime, looking), (looking, comfort), (comfort, used), (used, modern), (modern, chat), (chat, apps), (apps, quasseldroid), (quasseldroid, best), (best, free), (free, android), (android, irc), (irc, client), (client, get), (get, profile), (profile, picture), (picture, beautiful), (beautiful, ui), (ui, based), (based, material), (material, design), (design, feature), (feature, love)]

# %% [markdown]
# ##### Tri-grams

# %% [markdown]
# [(chat, comfortably, everywhere), (comfortably, everywhere, requires), (everywhere, requires, quassel), (requires, quassel, core), (quassel, core, work), (core, work, standalone), (work, standalone, irc), (standalone, irc, client), (irc, client, use), (client, use, irc), (use, irc, go), (irc, go, thanks), (go, thanks, quassel), (thanks, quassel, core), (quassel, core, never), (core, never, miss), (never, miss, anything), (miss, anything, always), (anything, always, entire), (always, entire, chat), (entire, chat, history), (chat, history, available), (history, available, scroll), (available, scroll, load), (scroll, load, older), (load, older, message), (older, message, core), (message, core, keep), (core, keep, notified), (keep, notified, someone), (notified, someone, message), (someone, message, even), (message, even, connection), (even, connection, meantime), (connection, meantime, looking), (meantime, looking, comfort), (looking, comfort, used), (comfort, used, modern), (used, modern, chat), (modern, chat, apps), (chat, apps, quasseldroid), (apps, quasseldroid, best), (quasseldroid, best, free), (best, free, android), (free, android, irc), (android, irc, client), (irc, client, get), (client, get, profile), (get, profile, picture), (profile, picture, beautiful), (picture, beautiful, ui), (beautiful, ui, based), (ui, based, material), (based, material, design), (material, design, feature), (design, feature, love)]

# %% [markdown]
# ##### Review Topics

# %% [markdown]
# Topic 0: thanks outside see beta working disconnecting bad desktop quassel stay
#
# Topic 1: work expected exactly look pretty effort usable well destined already
#
# Topic 2: brilliant app justworks changing reconnect perfectly nan major parenthesis constantly
#
# Topic 3: need dark close button called also one version prefer quassel
#
# Topic 4: migrating say custom netbook regex highlight thing tin miss phone
#
# Topic 5: quassel thankskeep update better even coming great core awesome effortlessly
#
# Topic 6: great work irc client move nicely best core far option
#
# Topic 7: realy earlier improvement two version looking galaxy nice thirty hundred
#
# Topic 8: love thanks irc whatever best solution device problem ui able
#
# Topic 9: moto nine working eighty really droid beta perfect well galaxy

# %% [markdown]
# ##### Analysis

# %% [markdown]
# Some of the review topics are related to the manually extracted features and bi-grams, and tri-grams.
#
# For example, Manually extracted features describe about "a beautiful UI based on Material Design". Review topics also mention about UI such as "look pretty, best solution device problem ui able,looking galaxy nice".
#
# Manually extracted feature - "Use IRC on the go" can also be related with summarized user feedback. Review topics mention about "great work irc client, love thanks irc".
#
# Manually extracted feature - "REQUIRES A QUASSEL CORE" summarized user feedback- "quassel stay, best core, quassel thankskeep update"
#
# However, there is nothing mentioned in the review topics about the features of " Chat comfortably,, Always have your entire chat history available, Be notified when someone messages you".
#
# Therefore, it is analysed that some of the topics are related to the functionalities and features of app, and some are not

# %% [markdown]
# ### IV. For this chosen ASSIGNED APP, extract topics of reviews (minimum of 5 Topics each described by 7 Words) for each of the competitor and similar apps

# %% [markdown]
# ### Similar application:   CoreIRC

# %%
description_irc = pd.read_csv("similartask4.csv")
#description_irc.head(1000)

# %%
#Text preprocessing
#description_irc['Review'] = description_irc['Review'].astype(str)  

def clean_text(headline):
      le=WordNetLemmatizer()
      word_tokens=word_tokenize(headline)
      tokens=[le.lemmatize(w) for w in word_tokens if w not in stop_words and len(w)>3]
      cleaned_text=" ".join(tokens)
      return cleaned_text

# %%
description_irc['cleaned_text']=description_irc['Review'].apply(clean_text)

# %%
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000)
vect_text=vect.fit_transform(description_irc['cleaned_text'])

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=10,
learning_method='online',random_state=42,max_iter=1) 
lda_top=lda_model.fit_transform(vect_text)

# %%
print("Similar app CoreIRC: ")
for i,topic in enumerate(lda_top[0]):
  print("Topic ",i,": ",topic*100,"%")
# Out:
# Similar app CoreIRC:
# Topic  0 :  1.8318134711712797 %
# Topic  1 :  1.8318193211223184 %
# Topic  2 :  1.8318127532569888 %
# Topic  3 :  1.832130350801258 %
# Topic  4 :  1.8318224412964694 %
# Topic  5 :  1.8318012919558728 %
# Topic  6 :  83.51332175557641 %
# Topic  7 :  1.831823950362347 %
# Topic  8 :  1.8318193896461035 %
# Topic  9 :  1.8318352748109266 %

# %%
vocab = vect.get_feature_names()
for i, comp in enumerate(lda_model.components_):
     vocab_comp = zip(vocab, comp)
     sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
     print("\nTopic "+str(i)+": ")
     for t in sorted_words:
            print(t[0],end=" ")
            #print("")
# Out:
# Topic 0:
# good coreirc functional hang joining would reinstalling anymore play pink
# Topic 1:
# nice button language system intuitive trial menu method store ssl
# Topic 2:
# close impossible review late every tried nicklist forward type answer
# Topic 3:
# language connect side please needs configuration readability overall confusing issues
# Topic 4:
# restart capable login definitely computer autocomplete ergo connected backup joining
# Topic 5:
# great dark port server please submit currently opened modern looking
# Topic 6:
# automatically client time android possible channel aesthetic also keyboard never
# Topic 7:
# wont specifically rejoin otherwise click beyond enough latest ircd menu
# Topic 8:
# love confusing modify definitely disconnect completion file intended dissconnect dark
# Topic 9:
# save event list thank back looking supplant stable joining great

# %% [markdown]
# ### V. How does the topics compare to the topics extracted from reviews of your ASSIGNED APP?
#
# Topics are related to assigned app such as coreirc, disconnect, latest ircd menu, channel aesthetic, restart capable
#
# Topics not related to assigned app are language system, configuration, save event list

# %% [markdown]
# ### Competitor app 1:  IRCCloud

# %%
description_irccloud = pd.read_csv("competitor1task4.csv")
#description_irccloud.head(1000)

# %%
description_irccloud['cleaned_text']=description_irccloud['Review'].apply(clean_text)
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000)
vect_text=vect.fit_transform(description_irccloud['cleaned_text'])
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=10,
learning_method='online',random_state=42,max_iter=1) 
lda_top=lda_model.fit_transform(vect_text)
print("Competitor app 1: IRCCloud ")
for i,topic in enumerate(lda_top[0]):
  print("Topic ",i,": ",topic*100,"%")
# Out:
# Competitor app 1: IRCCloud
# Topic  0 :  1.93357175739538 %
# Topic  1 :  1.9336306276174207 %
# Topic  2 :  1.933562710867466 %
# Topic  3 :  1.9337746800048565 %
# Topic  4 :  1.9335529139980034 %
# Topic  5 :  1.9335862628154992 %
# Topic  6 :  1.9336169819067315 %
# Topic  7 :  1.933721032790276 %
# Topic  8 :  82.59739427723159 %
# Topic  9 :  1.9335887553727795 %

# %%
vocab = vect.get_feature_names()
for i, comp in enumerate(lda_model.components_):
     vocab_comp = zip(vocab, comp)
     sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
     print("\nTopic "+str(i)+": ")
     for t in sorted_words:
            print(t[0],end=" ")
            #print("")
# Out:
# Topic 0:
# device terrible great irccloud sense getting lurker race work mobile
# Topic 1:
# best work serrr android unable thanks developer create charge junk
# Topic 2:
# favorite absolute better good cyrillic amazing skip make subscribe beta
# Topic 3:
# fine issue recommended working always works still would connecting nick
# Topic 4:
# account nice thanks thing perfect client phone theme need google
# Topic 5:
# perfect good great best greatest client stay hour connected cant
# Topic 6:
# good trial easy version paid register think without mo connect
# Topic 7:
# perfection update work requires loved great needed account need free
# Topic 8:
# client best used mobile android awesome work quite open even
# Topic 9:
# connect love service great user server client problem works free

# %% [markdown]
# ### V. How does the topics compare to the topics extracted from reviews of your ASSIGNED APP?
#
# Topics are related to assigned app such as irccloud, update work, connected, great user server
#
# Topics not related to assigned app are "need google, paid register".

# %% [markdown]
# ### Competitor app 2: 	 IRC for Android ™

# %%
description_ircandroid = pd.read_csv("competitor2task4.csv")
#description_irccloud.head(1000)

# %%
description_ircandroid['cleaned_text']=description_ircandroid['Review'].apply(clean_text)
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000)
vect_text=vect.fit_transform(description_ircandroid['cleaned_text'])
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=10,
learning_method='online',random_state=42,max_iter=1) 
lda_top=lda_model.fit_transform(vect_text)
print("Competitor app 2: IRC for Android ™ ")
for i,topic in enumerate(lda_top[0]):
  print("Topic ",i,": ",topic*100,"%")
# Out:
# Competitor app 2: IRC for Android ™
# Topic  0 :  1.9725906337930577 %
# Topic  1 :  1.972618141959361 %
# Topic  2 :  1.9725589818807892 %
# Topic  3 :  1.9725833441478238 %
# Topic  4 :  1.9726115855864246 %
# Topic  5 :  1.9726513812160444 %
# Topic  6 :  1.9725932281073413 %
# Topic  7 :  82.24647551142054 %
# Topic  8 :  1.9726350750475456 %
# Topic  9 :  1.97268211684105 %

# %%
vocab = vect.get_feature_names()
for i, comp in enumerate(lda_model.components_):
     vocab_comp = zip(vocab, comp)
     sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
     print("\nTopic "+str(i)+": ")
     for t in sorted_words:
            print(t[0],end=" ")
            #print("")
# Out:
# Topic 0:
# awesome still support file speed nick year figure broken send
# Topic 1:
# great well unheard market treat anyways developer android worth passwd
# Topic 2:
# excellent back background best user small mobile client show think
# Topic 3:
# good simply practical suck handle best notification constantly others authorization
# Topic 4:
# great client little play since using large apon keep join
# Topic 5:
# great also anymore best client android chatting functionality developer friendly
# Topic 6:
# connect excellent expected kick client used support log ever penny
# Topic 7:
# response available keyboard hide client quick part message join kept
# Topic 8:
# work works developer problem issue untime mirc well good responsive
# Topic 9:
# done client able server enjoy brilliantly well feature absolutely across

# %% [markdown]
# ### V. How does the topics compare to the topics extracted from reviews of your ASSIGNED APP?
# Topics are related to assigned app such as client able server, good responsive, well feature, background best, connect excellent
#
# Topics not related to assigned app are unheard market, chatting functionality,
#
# Review topics of assigned app does not mention about chattng functionality even though it is one of its feature.

# %% [markdown]
# # Competitor app 3: 	AndroIRC

# %%
description_ircandrol = pd.read_csv("competitor3task4.csv")
#description_ircandrol.head(1000)

# %%
description_ircandrol['cleaned_text']=description_ircandrol['Review'].apply(clean_text)
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000)
vect_text=vect.fit_transform(description_ircandrol['cleaned_text'])
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=10,
learning_method='online',random_state=42,max_iter=1) 
lda_top=lda_model.fit_transform(vect_text)
print("Competitor app 3: AndroIRC ")
for i,topic in enumerate(lda_top[0]):
  print("Topic ",i,": ",topic*100,"%")
# Out:
# Competitor app 3: AndroIRC
# Topic  0 :  1.9602849283586596 %
# Topic  1 :  1.9601987822463296 %
# Topic  2 :  1.9601832235564425 %
# Topic  3 :  82.35707230687464 %
# Topic  4 :  1.960249536442428 %
# Topic  5 :  1.9602365465579399 %
# Topic  6 :  1.9609270114877513 %
# Topic  7 :  1.9602721997496761 %
# Topic  8 :  1.9602280382920612 %
# Topic  9 :  1.960347426434086 %

# %%
vocab = vect.get_feature_names()
for i, comp in enumerate(lda_model.components_):
     vocab_comp = zip(vocab, comp)
     sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
     print("\nTopic "+str(i)+": ")
     for t in sorted_words:
            print(t[0],end=" ")
            #print("")
# Out:
# Topic 0:
# huawei enough doesnt rate support application fi auto wi hope
# Topic 1:
# excellent disconnecting sometimes fantastic never completion thank chat keep enjoy
# Topic 2:
# auto channel thxs mirc find better something crashes second used
# Topic 3:
# good great best nice work client android file would channel
# Topic 4:
# intuitive work android yaaic androuser still unusable lack seems supporting
# Topic 5:
# work simply soon really freenode confusing force crash nope time
# Topic 6:
# please update anymore even open xdcc four updated software okay
# Topic 7:
# apps good crash look open yayaya longer screen downloads crashing
# Topic 8:
# need command nick password location identify basic thank many open
# Topic 9:
# connect server wont auto even transfer work time error timeout

# %% [markdown]
# ### V. How does the topics compare to the topics extracted from reviews of your ASSIGNED APP?
#
# Topics are related to assigned app such as disconnecting sometimes, nice work client, connect server.
#
# Topics not related to assigned app are "chat keep enjoy, freenode, location identify"
#
# Review topics of assigned app does not mention about chattng functionality even though it is one of its feature.

# %% [markdown]
# ### BONUS for TASK 4 (8 Points): FINDING THE DOMINANT TOPIC FOR EACH REVIEW
#
#
# Topic that thas the highest percentage contribution is already found above

# %% [markdown]
# ### Assigned app Quasseldroid
#
# Dominant Topic: Topic 4
#
# migrating say custom netbook regex highlight thing tin miss phone

# %% [markdown]
# ### Similar app
#
# Dominant Topic: Topic 6
#
# automatically client time android possible channel aesthetic also keyboard never

# %% [markdown]
# ### Competitor app1
#
# Dominant Topic: Topic 8
#
# client best used mobile android awesome work quite open even

# %% [markdown]
# ### Competitor app2
#
# Dominant Topic: Topic 7
#
# response available keyboard hide client quick part message join kept

# %% [markdown]
# ### Competitor app3
#
# Dominant Topic: Topic 3
#
# good great best nice work client android file would channel

# %% [markdown]
# ### TASK 5: RECOMMENDATION

# %% [markdown]
# Two suggestions for app improvement
#
# #### 1: Compact mode
#
# It will help to reduce screen usage of UI. Other competitor apps have this feature.
#
# Commit messages, release notes, pull requests, are verified to make sure that this feature is not already addressed in the assigned app.
#
# #### 2: Location identify
#
# Other competitor apps has this feature and users are happy with this. It is verified from topic reviews of competitor app 3:AndroIRC.
#
# Commit messages, release notes, pull requests, are verified to make sure that this feature is not already addressed in the assigned app.
